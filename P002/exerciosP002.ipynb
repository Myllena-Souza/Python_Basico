# %%
import DataFruta as df

# %% [markdown]
# Teste das novas funções

# %%
n = 5
idades = df.ListaIdades.geraListaIdade(n)
salarios = df.ListaSalarios.geraListaSalarios(n)
print(idades)
print(40*"-")
print(salarios)
# Out:
# 37, 19, 55, 56, 57
# ----------------------------------------
# 13014.549482065464, 2831.9339564939055, 12682.67781186347, 9060.157342237464, 4849.460189434956

# %%
n = 5000
idades = df.ListaIdades.geraListaIdade(n)
salarios = df.ListaSalarios.geraListaSalarios(n)

# %% [markdown]
# Medindo desempenho para as idades

# %%
print("mediana")
# %timeit idades.mostraMediana()
print("maior")
# %timeit idades.mostraMenor()
print("menor")
# %timeit idades.mostraMaior()
# Out:
# mediana
# 295 µs ± 947 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# maior
# 296 µs ± 4.44 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# menor
# 297 µs ± 2.93 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# Medindo desempenho para os salários

# %%
print("mediana")
# %timeit salarios.mostraMediana()
print("maior")
# %timeit salarios.mostraMenor()
print("menor")
# %timeit salarios.mostraMaior()
# Out:
# mediana
# 455 µs ± 2.27 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# maior
# 464 µs ± 3.63 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# menor
# 454 µs ± 1.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# O modulo random do numpy oferece a função randint que gera um ndarray de numeros inteiros dentro do intervalo semiaberto [valorMinimo, valorMaximo)
# e para gerar numeros de ponto flutuante no intervalo fechado [valorMinimo, valorMaximo] utilizamos a função uniform

# %%
import numpy as np

def geraIdadesNP(n, iMin = 18, iMax = 64):
    return np.random.randint(iMin,iMax+1,n)

print(geraIdadesNP(10))

def geraSalariosNP(n, sMin = 1320, sMax = 13200):
    return np.random.uniform(sMin,sMax,n)

print(geraSalariosNP(10))
# Out:
# [64 54 62 31 25 34 34 48 33 19]
# [ 1444.70092297  5368.15906105  7998.11016329  6711.35323252
#   5873.157391    5513.48774781 11233.32536248  9483.63541891
#   4710.78101533 12616.71112425]

# %% [markdown]
# Criando ndarrays a partir das listas de salarios e idades computadas anteriormente

# %%
print(idades)
idadesNP = np.array(idades.getLista())
salariosNP = np.array(salarios.getLista())

print(idadesNP)
# Out:
# 23, 40, 29, 42, 30, 45, 39, 59, 63, 39, 31, 46, 45, 52, 35, 22, 64, 27, 61, 44, 40, 65, 58, 44, 57, 29, 26, 29, 33, 54, 22, 30, 40, 22, 38, 45, 27, 65, 58, 18, 55, 38, 47, 33, 62, 65, 23, 49, 35, 41, 29, 61, 29, 38, 48, 42, 47, 26, 58, 54, 23, 61, 20, 40, 31, 46, 56, 31, 21, 36, 45, 37, 58, 43, 26, 31, 53, 26, 43, 35, 44, 28, 26, 20, 55, 28, 58, 60, 52, 19, 24, 55, 20, 39, 28, 23, 29, 55, 33, 35, 53, 20, 39, 65, 64, 30, 21, 46, 46, 25, 56, 33, 58, 23, 35, 26, 50, 26, 18, 42, 18, 57, 31, 40, 19, 27, 56, 32, 45, 49, 19, 48, 35, 63, 47, 64, 18, 61, 61, 42, 44, 32, 34, 35, 26, 54, 63, 63, 40, 39, 30, 48, 61, 29, 44, 42, 57, 52, 46, 62, 42, 25, 31, 42, 38, 22, 57, 30, 37, 49, 20, 24, 32, 44, 28, 44, 34, 63, 46, 50, 61, 30, 33, 60, 42, 58, 46, 36, 51, 24, 40, 34, 64, 27, 39, 61, 22, 63, 36, 56, 65, 44, 22, 29, 30, 41, 37, 26, 45, 54, 30, 60, 60, 49, 23, 39, 18, 56, 51, 54, 48, 29, 41, 19, 29, 41, 65, 35, 49, 34, 56, 44, 27, 52, 37, 23, 44, 30, 33, 58, 43, 48, 54, 47, 28, 56, 19, 52, 65, 21
# ...

# %% [markdown]
# Testando os metodos numpy.max(), numpy.min(), numpy.median()
# para verificar o maior valor, menor valor e mediana, repectivamente.

# %% [markdown]
# Medindo desempenho para a nparray de Idades

# %%
print("mediana")
# %timeit np.median(idadesNP)
print("maior")
# %timeit np.max(idadesNP)
print("menor")
# %timeit np.min(idadesNP)
# Out:
# mediana
# 33.8 µs ± 650 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# maior
# 3.08 µs ± 39.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# menor
# 3.07 µs ± 35 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# Medindo desempenho para a nparray de Salários

# %%
print("mediana")
# %timeit np.median(salariosNP)
print("maior")
# %timeit np.max(salariosNP)
print("menor")
# %timeit np.min(salariosNP)
# Out:
# mediana
# 26.4 µs ± 1.09 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# maior
# 3.04 µs ± 92.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# menor
# 2.98 µs ± 9.59 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# É possivel notar que os metodos implementados pelo modulo numpy são em media 6 vezes mais eficientes que os metodos implementados no pacote DataFruta
